# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import requests
import matplotlib
import matplotlib.pyplot as pp
import ipywidgets as widgets
from ipywidgets import IntRangeSlider, SelectMultiple
from IPython.display import display


# %matplotlib inline

# %%
data = pd.read_csv("/Users/emiliekulesa/downloads/LDN_AQ_2020_2019.csv")
data
# Out:
#      Unnamed: 0    Date  Nitrogen Dioxide 2020  Nitrogen Dioxide 2019  \
# 0             0   Jan 1              44.989583              27.846809
# 1             1   Jan 2              20.117021              41.287234
# 2             2   Jan 3              17.861224              50.687500
# 3             3   Jan 4              34.404167              42.110638
# 4             4   Jan 5              16.930612              49.836957
# ..          ...     ...                    ...                    ...
# 189         189   Aug 5              32.460784              25.262000
# 190         190   Aug 6              17.457447              35.690000
# 191         191   Aug 7              18.083673              43.081633
# 192         192   Aug 8              40.606667              31.102083
# 193         193  Aug 13              27.543478              39.285106
#
#         CountryName  ConfirmedCases  ConfirmedDeaths  StringencyIndex  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import seaborn as sns

# %%
data.plot(y=['Nitrogen Dioxide 2020', 'Nitrogen Dioxide 2019'], x='Date')
pp.figure(figsize=(2000,500))
## still looking at the dotted lines for lock down days

# %%
## SO here is where I am having the issue. Date now formatted to datetime64(NS) but it'shaving trouble reading that and the count integers.

# %%
data = pd.read_csv("/Users/emiliekulesa/PycharmProjects/untitled1/python files lesson/traffic_stringency_airquality.csv")
data
# Out:
#      Unnamed: 0        Date    City          Transport mode   Count  \
# 0             0  2020-03-13  London                    Cars  284520
# 1             1  2020-03-13  London              Motorbikes     493
# 2             2  2020-03-13  London                   Buses   18856
# 3             3  2020-03-13  London                  Trucks   18778
# 4             4  2020-03-13  London                    Vans   39596
# ..          ...         ...     ...                     ...     ...
# 799         799  2020-08-13  London              Motorbikes     694
# 800         800  2020-08-13  London                   Buses   17570
# 801         801  2020-08-13  London                  Trucks   16873
# 802         802  2020-08-13  London                    Vans   36896
# 803         803  2020-08-13  London  Pedestrians & cyclists   36843
#
#      Nitrogen Dioxide_ugm-3_LDN     CountryName  ConfirmedCases  \
# 0                     31.193478  United Kingdom          1282.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas as pd
file = ("/Users/emiliekulesa/PycharmProjects/untitled1/python files lesson/traffic_stringency_airquality.csv")
dataframe = pd.read_csv(file)
dataframe
# Out:
#      Unnamed: 0        Date    City          Transport mode   Count  \
# 0             0  2020-03-13  London                    Cars  284520
# 1             1  2020-03-13  London              Motorbikes     493
# 2             2  2020-03-13  London                   Buses   18856
# 3             3  2020-03-13  London                  Trucks   18778
# 4             4  2020-03-13  London                    Vans   39596
# ..          ...         ...     ...                     ...     ...
# 799         799  2020-08-13  London              Motorbikes     694
# 800         800  2020-08-13  London                   Buses   17570
# 801         801  2020-08-13  London                  Trucks   16873
# 802         802  2020-08-13  London                    Vans   36896
# 803         803  2020-08-13  London  Pedestrians & cyclists   36843
#
#      Nitrogen Dioxide_ugm-3_LDN     CountryName  ConfirmedCases  \
# 0                     31.193478  United Kingdom          1282.0
# ...

# %%
dataframe.info('date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  804 non-null    int64
#  1   Date                        804 non-null    object
#  2   City                        804 non-null    object
#  3   Transport mode              804 non-null    object
#  4   Count                       804 non-null    int64
#  5   Nitrogen Dioxide_ugm-3_LDN  804 non-null    float64
#  6   CountryName                 804 non-null    object
#  7   ConfirmedCases              804 non-null    float64
#  8   ConfirmedDeaths             804 non-null    float64
#  9   StringencyIndex             804 non-null    float64
#  10  StringencyIndexForDisplay   804 non-null    float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 69.2+ KB

# %%
file = ("/Users/emiliekulesa/PycharmProjects/untitled1/python files lesson/traffic_stringency_airquality.csv")
date = ["Date"]
london_air_quality = (
    pd
    .read_csv(file,
             usecols = ['Date', 'Transport mode', 'Count', 'Nitrogen Dioxide_ugm-3_LDN', 'StringencyIndexForDisplay'],
             parse_dates=date)
)
print(london_air_quality.head())
print(london_air_quality.info())
# Out:
#         Date Transport mode   Count  Nitrogen Dioxide_ugm-3_LDN  \
# 0 2020-03-13           Cars  284520                   31.193478
# 1 2020-03-13     Motorbikes     493                   31.193478
# 2 2020-03-13          Buses   18856                   31.193478
# 3 2020-03-13         Trucks   18778                   31.193478
# 4 2020-03-13           Vans   39596                   31.193478
#
#    StringencyIndexForDisplay
# 0                      12.96
# 1                      12.96
# 2                      12.96
# 3                      12.96
# 4                      12.96
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        804 non-null    datetime64[ns]
#  1   Transport mode              804 non-null    object
#  2   Count                       804 non-null    int64
# ...

# %%
sns.relplot(
    file = dataframe[dataframe['Transport mode'] == 'Cars'],
    y = "Count",
    x = "Date",
    kind = 'line',
    height = 8,
    aspect = 3
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-471e546e364c> in <module>
#       2     file = dataframe[dataframe['Transport mode'] == 'Cars'],
#       3     y = "Count",
# ----> 4     x = Date,
#       5     kind = 'line',
#       6     height = 8,
#
# NameError: name 'Date' is not defined
